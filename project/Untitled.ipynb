# %%
# def read_dnaFile(seq):
string=''
with open('../Data/example.fasta') as file:

    for line in file:
        # print(line)
        if line.startswith('>'):
            pass
            # print(line)

                  
        else: 
            string+= line.replace('\n','')
print(string)
    # return(string)


# dna_string=read_dnaFile('../Data/example.fasta')
# print(dna_string)
# Out:
# ...
